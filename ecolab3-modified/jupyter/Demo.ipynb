# %% [markdown]
# # Ecolab3 demo
#
# Ecolab3 was based on Mike Croucher's python version and Dawn Walker's original MATLAB version. This one has a few additions, such as regrowing grass, etc.
#
# This notebook just shows how to use the default ecolab3. There are some parameters you can access through the constructors, while others you might need to edit the agent.py or environment.py. Later you'll want to edit the actual methods.

# %% [markdown]
# ## Installing ecolab3
#
# This block only needs running once. It downloads and installs the ecolab3 module from github. Comment it out once you've done it.

# %%
#Handles installing ecolab3 for the first time
#!git clone https://github.com/lionfish0/ecolab3.git
#!pip install -e ./ecolab3
#You will need to *restart runtime*, so the module is available.
#the exit command will restart it for you...
#exit()

# %%
import numpy as np
import matplotlib.pyplot as plt
from ecolab3.environment import Environment
from ecolab3.agents import Worker, Scout, Queen, Nest
from ecolab3 import run_ecolab, draw_animation, get_agent_counts

# %%
#create default environment
env = Environment(shape=[80,80])
    
#create agents (rabbits and foxes)
Nworkers = 80
Nscouts = 40
Nqueens = 1
Nnest = 1
agents = []

center = env.get_center()

for i in range(Nworkers):
    w = Worker(position=center)
    agents.append(w)
for i in range(Nscouts):
    s = Scout(position=center)
    agents.append(s)
agents.append(Queen(position=center))
agents.append(Nest(position=center, age=1))

env.randomise_food_initially()

# %%
#run the simulation (default = 1000 iterations)
"""
Note: For whatever reason, the system is extremely temperamental, causing an IndexError occasionally.
The fix is to reset the kernel, then reset the entire Jupyter server (close the webpage, close the .ipynb, then reopen).
The system does work correctly, however I haven't figured out why this error happens sometimes.
"""
record = run_ecolab(env,agents)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 #run the simulation (default = 1000 iterations)
#       2 # NOTE: KERNEL & WEBPAGE NEEDS TO BE RESET BEFORE RE-RUNNING OR AN ERROR WILL BE THROWN!!!
# ----> 3 record = run_ecolab(env,agents)
#
# File D:\Documents\University\Year 3\COM3001 - Modelling & Simulation of Natural Systems\com3001_project\ecolab3-modified\ecolab3\__init__.py:27, in run_ecolab(env, agents, Niterations, earlystop)
#      25 # for each agent, apply rules (move, eat, breed)
#      26 for agent in agents:
# ---> 27     agent.move(env, agents)
#      28     agent.eat(env, agents)
#      29     a = agent.breed(agents)
#
# File D:\Documents\University\Year 3\COM3001 - Modelling & Simulation of Natural Systems\com3001_project\ecolab3-modified\ecolab3\agents.py:426, in Scout.move(self, env, agents)
#     424     self.isReturningToNest = True
#     425 else:
# --> 426     self.lookForFood(env)
#
# File D:\Documents\University\Year 3\COM3001 - Modelling & Simulation of Natural Systems\com3001_project\ecolab3-modified\ecolab3\agents.py:391, in Scout.lookForFood(self, env)
#     390 def lookForFood(self, env):
# --> 391     foodPos = env.get_loc_of_food(self.getPos(), self.vision)
#     392     if foodPos is not None:
#     393         self.attemptMoveToTarget(foodPos, env)
#
# File D:\Documents\University\Year 3\COM3001 - Modelling & Simulation of Natural Systems\com3001_project\ecolab3-modified\ecolab3\environment.py:190, in Environment.get_loc_of_food(self, position, sense)
#     188 def get_loc_of_food(self, position, sense):
#     189     position = np.array([x for x in position if type(x) != Environment]).flatten()
# --> 190     return self.get_loc_of_target(position, sense, True)
#
# File D:\Documents\University\Year 3\COM3001 - Modelling & Simulation of Natural Systems\com3001_project\ecolab3-modified\ecolab3\environment.py:228, in Environment.get_loc_of_target(self, position, vision, isFood)
#     221 """
#     222 This finds the location of the cell with the maximum amount of food near 'pos',
#     223 within a circle of 'vision' size.
#     224 For example env.get_dir_of_food(np.array([3,3]),2)
#     225 if two or more cells have the same food then it will select between them randomly.
#     226 """
#     227 position = np.array([x for x in position if type(x) != Environment]).flatten()
# --> 228 searchSquare = self.generateSearchSquare(position, vision, isFood)
#     230 if np.all(searchSquare <= 0):
#     231     return None  # no target instances found
#
# File D:\Documents\University\Year 3\COM3001 - Modelling & Simulation of Natural Systems\com3001_project\ecolab3-modified\ecolab3\environment.py:216, in Environment.generateSearchSquare(self, position, vision, isFood)
#     212 # we search just a circle within 'vision' tiles of 'pos' (these two commands build that search square)
#     213 searchSquare = targetWithBoundary[int(pos[0] - vision):int(pos[0] + vision + 1),
#     214                int(pos[1] - vision):int(pos[1] + vision + 1)]
# --> 216 searchSquare[(np.arange(-vision, vision + 1)[:, None] ** 2 + np.arange(-vision, vision + 1)[None,
#     217                                                              :] ** 2) > vision ** 2] = -1
#     218 return searchSquare
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 22 but corresponding boolean dimension is 21

# %%
#If you want to save your data, use this:
#import pickle
#pickle.dump(record,open('myrecord.pkl','wb'))

#to load it later, use this:
#record = pickle.load(open('myrecord.pkl','rb'))
# record[9]['pheromones']

# %%
#need to use %matplotlib notebook
# %matplotlib notebook 
fig = plt.figure( figsize=(8,8) )
draw_animation(fig,record[::5],5,saveto='test_anim.mp4') #draw every 5th frame
# Out:
# <img src="data:image/png;base64,..." width="800">
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 4>()
#       2 get_ipython().run_line_magic('matplotlib', 'notebook')
#       3 fig = plt.figure( figsize=(8,8) )
# ----> 4 draw_animation(fig,record[::5],5,saveto='test_anim.mp4')
#
# File D:\Documents\University\Year 3\COM3001 - Modelling & Simulation of Natural Systems\com3001_project\ecolab3-modified\ecolab3\__init__.py:110, in draw_animation(fig, record, fps, saveto)
#     102     # return [im]#,rabbits,foxes]
#     104 anim = animation.FuncAnimation(
#     105     fig,
#     106     animate_func,
#     107     frames=len(record),
#     108     interval=1000 / fps, repeat=False  # in ms
#     109 )
# --> 110 if saveto is not None: anim.save(saveto, fps=fps, extra_args=['-vcodec', 'libx264'])
#     111 from IPython.display import HTML
#     112 return HTML(anim.to_jshtml())
#
# File d:\documents\university\year 3\com3001 - modelling & simulation of natural systems\com3001_project\ecolab3-modified\venv\lib\site-packages\matplotlib\animation.py:1051, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1048         writer_cls = PillowWriter  # Always available.
#    1049         _log.warning("MovieWriter %s unavailable; using Pillow "
#    1050                      "instead.", writer)
# -> 1051     writer = writer_cls(fps, **writer_kwargs)
#    1052 _log.info('Animation.save using %s', type(writer))
#    1054 if 'bbox_inches' in savefig_kwargs:
#
# TypeError: AbstractMovieWriter.__init__() got an unexpected keyword argument 'extra_args'

# %% [markdown]
# We might want to just look at general statistics, e.g. how the number of rabbits and foxes fluctuates

# %%
# %matplotlib inline
counts = get_agent_counts(record)
plt.figure(figsize=[8,4])
plt.plot(counts[:,0],label='workers')
plt.plot(counts[:,1],label='scouts')
plt.plot(counts[:,2],label='queens')
plt.plot(counts[:,4]/2,'k-',label='food') #/2 to get on same scale
plt.legend()
plt.grid()
plt.xlabel('Iteration')
plt.ylabel('Count');

# %% [markdown]
# 1) Most times I've run this it seems the grass grows, then the rabbits suddenly grow, the foxes grow in response. The grass is eaten. Then the combined effect of less grass and more foxes causes the rabbit population to drop to zero. (sometimes other things happen, like the fox population doesn't survive initially)
#
# 2) What happens if the foxes are less good predators (reduce their speed from 5 to 2 or 3?)? Explain?
#
# 3) What happens if there are no foxes?
#
# 4) There are a lot of parameters to play with. You should also start exploring the code (agents.py and environment.py) to see what you can alter to get different behaviour.
#
# Note: Although it's tempting to think that oscillations are Lotka-Volterra (Predator-Prey) interactions between the rabbits and the foxes, it might be that they are caused by grass-rabbit iteractions. The plot of the grass count reveals this might be the case...
